# %% [markdown]
# ## Connect to Meilisearch

# %%
import meilisearch

meilisearch_client = meilisearch.Client("http://localhost:7700", "aStrongMasterKey")
print("Successfully connected to Meilisearch!")
# Out:
# Successfully connected to Meilisearch!

# %% [markdown]
# ## Create a dump

# %%
task = meilisearch_client.create_dump()
meilisearch_client.wait_for_task(task.task_uid)
# Out:
# Task(uid=1010, index_uid=None, status='succeeded', type='dumpCreation', details={'dumpUid': '20251101-064908777'}, error=None, canceled_by=None, duration='PT0.097821094S', enqueued_at=datetime.datetime(2025, 11, 1, 6, 49, 8, 771447), started_at=datetime.datetime(2025, 11, 1, 6, 49, 8, 775893), finished_at=datetime.datetime(2025, 11, 1, 6, 49, 8, 873715))

# %%
meil
